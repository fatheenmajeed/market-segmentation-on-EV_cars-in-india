# %% [markdown]
# # **market segmentation**
# market segmentation is a process of dividing a broad customer or a business market,
#
# normally consisting of existing and potential customers,
#
# into sub-groups of customer based on some type of shared characteristics

# %% [markdown]
# # objectives

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/IEA-EV-dataEV salesHistoricalCars.csv')
df
# Out:
#      India  Historical                       EV stock  Cars   BEV  2010  \
# 0    India  Historical                       EV sales  Cars   BEV  2010
# 1    India  Historical                 EV sales share  Cars    EV  2010
# 2    India  Historical                 EV stock share  Cars    EV  2010
# 3    India  Historical           Oil displacement Mbd  Cars    EV  2010
# 4    India  Historical  Oil displacement, million lge  Cars    EV  2010
# ..     ...         ...                            ...   ...   ...   ...
# 98   India  Historical                 EV sales share  Cars    EV  2023
# 99   India  Historical                       EV sales  Cars   BEV  2023
# 100  India  Historical                       EV stock  Cars   BEV  2023
# 101  India  Historical                       EV stock  Cars  PHEV  2023
# 102  India  Historical             Electricity demand  Cars    EV  2023
#
#                           Vehicles            880
# 0                         Vehicles     450.000000
# ...

# %%
df.tail()
# Out:
#      India  Historical            EV stock  Cars   BEV  2010  Vehicles  \
# 98   India  Historical      EV sales share  Cars    EV  2023   percent
# 99   India  Historical            EV sales  Cars   BEV  2023  Vehicles
# 100  India  Historical            EV stock  Cars   BEV  2023  Vehicles
# 101  India  Historical            EV stock  Cars  PHEV  2023  Vehicles
# 102  India  Historical  Electricity demand  Cars    EV  2023       GWh
#
#           880
# 98        2.0
# 99    82000.0
# 100  150000.0
# 101     390.0
# 102     410.0

# %%
df.isnull().sum()
# Out:
# India         0
# Historical    0
# EV stock      0
# Cars          0
# BEV           0
# 2010          0
# Vehicles      0
# 880           0
# dtype: int64

# %%
df.shape
# Out:
# (103, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   India       103 non-null    object
#  1   Historical  103 non-null    object
#  2   EV stock    103 non-null    object
#  3   Cars        103 non-null    object
#  4   BEV         103 non-null    object
#  5   2010        103 non-null    int64
#  6   Vehicles    103 non-null    object
#  7   880         103 non-null    float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.6+ KB

# %%
df.describe()
# Out:
#               2010            880
# count   103.000000     103.000000
# mean   2017.475728    4408.997883
# std       4.084511   18734.561395
# min    2010.000000       0.000022
# 25%    2014.000000       0.021000
# 50%    2018.000000       2.600000
# 75%    2021.000000     410.000000
# max    2023.000000  150000.000000

# %%
df.columns
# Out:
# Index(['India', 'Historical', 'EV stock', 'Cars', 'BEV', '2010', 'Vehicles',
#        '880'],
#       dtype='object')

# %%
df['EV stock'].unique()
# Out:
# array(['EV sales', 'EV sales share', 'EV stock share',
#        'Oil displacement Mbd', 'Oil displacement, million lge',
#        'EV stock', 'Electricity demand'], dtype=object)

# %%
df['EV stock'].nunique()
# Out:
# 7

# %%
df['BEV'].unique()
# Out:
# array(['BEV', 'EV', 'PHEV', 'FCEV'], dtype=object)

# %%
df['BEV'].nunique()
# Out:
# 4

# %%
df['Vehicles'].unique()
# Out:
# array(['Vehicles', 'percent', 'Milion barrels per day',
#        'Oil displacement, million lge', 'GWh'], dtype=object)

# %%
df['Vehicles'].nunique()
# Out:
# 5

# %%
df_cat = df.select_dtypes(object)
df_cat
# Out:
#      India  Historical                       EV stock  Cars   BEV  \
# 0    India  Historical                       EV sales  Cars   BEV
# 1    India  Historical                 EV sales share  Cars    EV
# 2    India  Historical                 EV stock share  Cars    EV
# 3    India  Historical           Oil displacement Mbd  Cars    EV
# 4    India  Historical  Oil displacement, million lge  Cars    EV
# ..     ...         ...                            ...   ...   ...
# 98   India  Historical                 EV sales share  Cars    EV
# 99   India  Historical                       EV sales  Cars   BEV
# 100  India  Historical                       EV stock  Cars   BEV
# 101  India  Historical                       EV stock  Cars  PHEV
# 102  India  Historical             Electricity demand  Cars    EV
#
#                           Vehicles
# 0                         Vehicles
# 1                          percent
# 2                          percent
# ...

# %%
#converting categorical data to numerical data

# %%
df.dtypes
# Out:
# India          object
# Historical     object
# EV stock       object
# Cars           object
# BEV            object
# 2010            int64
# Vehicles       object
# 880           float64
# dtype: object

# %%
df
# Out:
#      India  Historical                       EV stock  Cars   BEV  2010  \
# 0    India  Historical                       EV sales  Cars   BEV  2010
# 1    India  Historical                 EV sales share  Cars    EV  2010
# 2    India  Historical                 EV stock share  Cars    EV  2010
# 3    India  Historical           Oil displacement Mbd  Cars    EV  2010
# 4    India  Historical  Oil displacement, million lge  Cars    EV  2010
# ..     ...         ...                            ...   ...   ...   ...
# 98   India  Historical                 EV sales share  Cars    EV  2023
# 99   India  Historical                       EV sales  Cars   BEV  2023
# 100  India  Historical                       EV stock  Cars   BEV  2023
# 101  India  Historical                       EV stock  Cars  PHEV  2023
# 102  India  Historical             Electricity demand  Cars    EV  2023
#
#                           Vehicles            880
# 0                         Vehicles     450.000000
# ...

# %%
df['EV stock'].unique()
# Out:
# array(['EV sales', 'EV sales share', 'EV stock share',
#        'Oil displacement Mbd', 'Oil displacement, million lge',
#        'EV stock', 'Electricity demand'], dtype=object)

# %%
df['BEV'].unique()
# Out:
# array(['BEV', 'EV', 'PHEV', 'FCEV'], dtype=object)

# %%
df['Vehicles'].unique()
# Out:
# array(['Vehicles', 'percent', 'Milion barrels per day',
#        'Oil displacement, million lge', 'GWh'], dtype=object)

# %%
df.iloc[:,[2,4,6]]
# Out:
#                           EV stock   BEV                       Vehicles
# 0                         EV sales   BEV                       Vehicles
# 1                   EV sales share    EV                        percent
# 2                   EV stock share    EV                        percent
# 3             Oil displacement Mbd    EV         Milion barrels per day
# 4    Oil displacement, million lge    EV  Oil displacement, million lge
# ..                             ...   ...                            ...
# 98                  EV sales share    EV                        percent
# 99                        EV sales   BEV                       Vehicles
# 100                       EV stock   BEV                       Vehicles
# 101                       EV stock  PHEV                       Vehicles
# 102             Electricity demand    EV                            GWh
#
# [103 rows x 3 columns]

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
categorical_features =['EV stock','BEV','Vehicles']
for i in categorical_features:
  df[i] = le.fit_transform(df[i])

# %%
df
# Out:
#      India  Historical  EV stock  Cars  BEV  2010  Vehicles            880
# 0    India  Historical         0  Cars    0  2010         3     450.000000
# 1    India  Historical         1  Cars    1  2010         4       0.021000
# 2    India  Historical         3  Cars    1  2010         4       0.005000
# 3    India  Historical         5  Cars    1  2010         1       0.000022
# 4    India  Historical         6  Cars    1  2010         2       1.300000
# ..     ...         ...       ...   ...  ...   ...       ...            ...
# 98   India  Historical         1  Cars    1  2023         4       2.000000
# 99   India  Historical         0  Cars    0  2023         3   82000.000000
# 100  India  Historical         2  Cars    0  2023         3  150000.000000
# 101  India  Historical         2  Cars    3  2023         3     390.000000
# 102  India  Historical         4  Cars    1  2023         0     410.000000
#
# [103 rows x 8 columns]

# %%
df['2010'].dtype
# Out:
# dtype('int64')

# %%
#droping india,Historical,Cars columns because its constant
df=df.drop(['India','Historical','Cars'],axis=1)

# %%
#when there is no variable like target
#or when we dont have any column to pridict it is called as unsupervised learning

# %%
df
# Out:
#      EV stock  BEV  2010  Vehicles            880
# 0           0    0  2010         3     450.000000
# 1           1    1  2010         4       0.021000
# 2           3    1  2010         4       0.005000
# 3           5    1  2010         1       0.000022
# 4           6    1  2010         2       1.300000
# ..        ...  ...   ...       ...            ...
# 98          1    1  2023         4       2.000000
# 99          0    0  2023         3   82000.000000
# 100         2    0  2023         3  150000.000000
# 101         2    3  2023         3     390.000000
# 102         4    1  2023         0     410.000000
#
# [103 rows x 5 columns]

# %%
#checking the density of each column(distribution like normal distribution or Skewed Distributions)
plt.figure(figsize=(30,45))
for i, col in enumerate(df.columns):
    if df[col].dtype !='object':
      ax=plt.subplot(9,2,i+1)
      sns.kdeplot(df[col],ax=ax)
      plt.xlabel(col)
plt.show()
#non of them is getting ND

# %%
# Get the actual number of columns in the DataFrame
num_columns = len(df.columns)

plt.figure(figsize=(30, 45))
for i in range(num_columns):
    plt.subplot((num_columns + 1) // 2, 2, i + 1)  # Adjust the subplot grid
    sns.histplot(df[df.columns[i]], kde=True,
                 line_kws={'color': 'r', 'lw': 3, 'label': 'KDE'},  # Setting color and linewidth for KDE
                 color='g')  # Setting color for histogram
    plt.title(df.columns[i])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
#Scaling the DataFrame

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
scalar_df=scalar.fit_transform(df)

# %%
scalar_df
# Out:
# array([[-1.27810856e+00, -1.17315033e+00, -1.83921278e+00,
#          2.46081035e-01, -2.12353912e-01],
#        [-7.94118922e-01,  2.32306997e-02, -1.83921278e+00,
#          1.12009298e+00, -2.36490020e-01],
#        [ 1.73860356e-01,  2.32306997e-02, -1.83921278e+00,
#          1.12009298e+00, -2.36490878e-01],
#        [ 1.14183963e+00,  2.32306997e-02, -1.83921278e+00,
#         -1.50194287e+00, -2.36491145e-01],
#        [ 1.62582927e+00,  2.32306997e-02, -1.83921278e+00,
#         -6.27930916e-01, -2.36421417e-01],
#        [ 1.14183963e+00,  2.32306997e-02, -1.59318821e+00,
#         -1.50194287e+00, -2.36491144e-01],
#        [ 1.62582927e+00,  2.32306997e-02, -1.59318821e+00,
#         -6.27930916e-01, -2.36351687e-01],
#        [ 1.73860356e-01,  2.32306997e-02, -1.59318821e+00,
#          1.12009298e+00, -2.36490787e-01],
#        [-7.94118922e-01,  2.32306997e-02, -1.59318821e+00,
#          1.12009298e+00, -2.36488143e-01],
# ...

# %%
pd.DataFrame(scalar_df)
# Out:
#             0         1         2         3         4
# 0   -1.278109 -1.173150 -1.839213  0.246081 -0.212354
# 1   -0.794119  0.023231 -1.839213  1.120093 -0.236490
# 2    0.173860  0.023231 -1.839213  1.120093 -0.236491
# 3    1.141840  0.023231 -1.839213 -1.501943 -0.236491
# 4    1.625829  0.023231 -1.839213 -0.627931 -0.236421
# ..        ...       ...       ...       ...       ...
# 98  -0.794119  0.023231  1.359107  1.120093 -0.236384
# 99  -1.278109 -1.173150  1.359107  0.246081  4.161849
# 100 -0.310129 -1.173150  1.359107  0.246081  7.809254
# 101 -0.310129  2.415993  1.359107  0.246081 -0.215572
# 102  0.657850  0.023231  1.359107 -2.375955 -0.214499
#
# [103 rows x 5 columns]

# %%
#pca
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
principal_components=pca.fit_transform(pd.DataFrame(scalar_df))
pca_df=pd.DataFrame(data=principal_components,columns=['PCA1','PCA2'])
pca_df
# Out:
#          PCA1      PCA2
# 0    0.997401 -2.006902
# 1    1.086106 -1.227837
# 2    0.421433 -1.313906
# 3   -1.960311 -1.337258
# 4   -1.720271 -1.401200
# ..        ...       ...
# 98   1.299571  1.022575
# 99   2.452828  0.130649
# 100  2.823784 -0.049530
# 101  0.111862  2.684674
# 102 -1.980653  0.976529
#
# [103 rows x 2 columns]

# %%
#Dimensionally reduction
#converting the DataFrame into 2D DataFrame for visualization

# %%
#pca

# %%
#hyperparameter tuning
#Finding K value elbow method

# %% [markdown]
# # hyperparameter tuning
# #  finding 'K' value by Elbow Method

# %%
from sklearn.cluster import KMeans

# %%
inertia = []
range_val = range(1, 15)
for i in range_val:
    km = KMeans(n_clusters=i, random_state=42)
    km.fit(pd.DataFrame(scalar_df))
    inertia.append(km.inertia_)

plt.plot(range_val, inertia,'bx-')  # Fixed variable name here
plt.xlabel('Values of K')  # Fixed typo in 'Values og K'
plt.ylabel('Inertia')
plt.title('The Elbow Method using Inertia')
plt.show()

# %%
#so it falls on 4(at k value 4 the graph is taking a ELBOW)

# %% [markdown]
# # model building using KMeans

# %%
kmeans=KMeans(4)
kmeans.fit(pd.DataFrame(scalar_df))
pca_df_kmeans=pd.concat([pca_df,pd.DataFrame({'cluster':kmeans.labels_})],axis=1)
pca_df_kmeans
# Out:
#          PCA1      PCA2  cluster
# 0    0.997401 -2.006902        1
# 1    1.086106 -1.227837        1
# 2    0.421433 -1.313906        1
# 3   -1.960311 -1.337258        0
# 4   -1.720271 -1.401200        0
# ..        ...       ...      ...
# 98   1.299571  1.022575        1
# 99   2.452828  0.130649        3
# 100  2.823784 -0.049530        3
# 101  0.111862  2.684674        2
# 102 -1.980653  0.976529        0
#
# [103 rows x 3 columns]

# %%
plt.figure(figsize=(8,8))
ax=sns.scatterplot(x='PCA1',y='PCA2',hue='cluster',data=pca_df_kmeans,palette='rainbow')
plt.title('clustering using kmeans algorithms')
plt.show()

# %%
#find all cluster center
cluster_centers=pd.DataFrame(data=kmeans.cluster_centers_,columns=[df.columns])
#inverse transform the data
cluster_centers=scalar.inverse_transform(cluster_centers)
cluster_centers=pd.DataFrame(data=cluster_centers,columns=[df.columns])
cluster_centers
# Out:
#    EV stock       BEV         2010  Vehicles           880
# 0  5.272727  1.000000  2017.181818  1.272727     21.277546
# 1  1.529412  0.549020  2016.156863  3.549020   1967.737704
# 2  1.066667  2.666667  2021.266667  3.000000     71.333333
# 3  1.000000  0.000000  2022.500000  3.000000  88000.000000

# %%
#creating a target column
cluster_df=pd.concat([df,pd.DataFrame({'cluster':kmeans.labels_})],axis=1)
cluster_df
# Out:
#      EV stock  BEV  2010  Vehicles            880  cluster
# 0           0    0  2010         3     450.000000        1
# 1           1    1  2010         4       0.021000        1
# 2           3    1  2010         4       0.005000        1
# 3           5    1  2010         1       0.000022        0
# 4           6    1  2010         2       1.300000        0
# ..        ...  ...   ...       ...            ...      ...
# 98          1    1  2023         4       2.000000        1
# 99          0    0  2023         3   82000.000000        3
# 100         2    0  2023         3  150000.000000        3
# 101         2    3  2023         3     390.000000        2
# 102         4    1  2023         0     410.000000        0
#
# [103 rows x 6 columns]

# %%
cluster_df['cluster'].unique()
# Out:
# array([1, 0, 2, 3], dtype=int32)

# %%
cluster_0_df =cluster_df[cluster_df['cluster']==0]
cluster_0_df
# Out:
#      EV stock  BEV  2010  Vehicles         880  cluster
# 3           5    1  2010         1    0.000022        0
# 4           6    1  2010         2    1.300000        0
# 5           5    1  2011         1    0.000045        0
# 6           6    1  2011         2    2.600000        0
# 15          5    1  2012         1    0.000045        0
# 16          6    1  2012         2    2.600000        0
# 17          5    1  2013         1    0.000050        0
# 18          6    1  2013         2    2.900000        0
# 27          5    1  2014         1    0.000065        0
# 28          6    1  2014         2    3.700000        0
# 29          5    1  2015         1    0.000074        0
# 30          6    1  2015         2    4.200000        0
# 39          5    1  2016         1    0.000084        0
# 40          6    1  2016         2    4.800000        0
# 41          5    1  2017         1    0.000100        0
# 42          6    1  2017         2    5.800000        0
# ...

# %%
cluster_1_df =cluster_df[cluster_df['cluster']==1]
cluster_1_df
# Out:
#     EV stock  BEV  2010  Vehicles         880  cluster
# 0          0    0  2010         3    450.0000        1
# 1          1    1  2010         4      0.0210        1
# 2          3    1  2010         4      0.0050        1
# 7          3    1  2011         4      0.0067        1
# 8          1    1  2011         4      0.0560        1
# 9          0    0  2011         3   1400.0000        1
# 10         2    0  2011         3   1300.0000        1
# 11         2    0  2012         3   2800.0000        1
# 12         0    0  2012         3    190.0000        1
# 13         1    1  2012         4      0.0072        1
# 14         3    1  2012         4      0.0120        1
# 19         3    1  2013         4      0.0120        1
# 20         1    1  2013         4      0.0160        1
# 21         0    0  2013         3    410.0000        1
# 22         2    0  2013         3   2900.0000        1
# 23         2    0  2014         3   3400.0000        1
# ...

# %%
cluster_2_df =cluster_df[cluster_df['cluster']==2]
cluster_2_df
# Out:
#      EV stock  BEV  2010  Vehicles    880  cluster
# 56          0    3  2019         3    7.0        2
# 60          2    3  2019         3    7.0        2
# 63          2    3  2020         3   50.0        2
# 67          0    3  2020         3   43.0        2
# 74          0    3  2021         3   50.0        2
# 75          0    2  2021         3    1.0        2
# 76          2    2  2021         3    1.0        2
# 80          2    3  2021         3  100.0        2
# 83          2    3  2022         3  120.0        2
# 87          2    2  2022         3    3.0        2
# 88          0    2  2022         3    2.0        2
# 89          0    3  2022         3   23.0        2
# 96          0    3  2023         3  270.0        2
# 97          2    2  2023         3    3.0        2
# 101         2    3  2023         3  390.0        2

# %%
cluster_3_df =cluster_df[cluster_df['cluster']==3]
cluster_3_df
# Out:
#      EV stock  BEV  2010  Vehicles       880  cluster
# 84          2    0  2022         3   72000.0        3
# 85          0    0  2022         3   48000.0        3
# 99          0    0  2023         3   82000.0        3
# 100         2    0  2023         3  150000.0        3

# %%
sns.countplot(x='cluster',data=cluster_df)
# Out:
# <Axes: xlabel='cluster', ylabel='count'>

# %%
for c in cluster_df.drop(['cluster'],axis=1):
  grid=sns.FacetGrid(cluster_df,col='cluster')
  grid=grid.map(plt.hist,c)
plt.show()

# %%
import joblib
joblib.dump(kmeans,'kmeans.pkl')
# Out:
# ['kmeans.pkl']

# %%
cluster_df.to_csv('EV_sales_cluster_df.csv')

# %%
cluster_df
# Out:
#      EV stock  BEV  2010  Vehicles            880  cluster
# 0           0    0  2010         3     450.000000        1
# 1           1    1  2010         4       0.021000        1
# 2           3    1  2010         4       0.005000        1
# 3           5    1  2010         1       0.000022        0
# 4           6    1  2010         2       1.300000        0
# ..        ...  ...   ...       ...            ...      ...
# 98          1    1  2023         4       2.000000        1
# 99          0    0  2023         3   82000.000000        3
# 100         2    0  2023         3  150000.000000        3
# 101         2    3  2023         3     390.000000        2
# 102         4    1  2023         0     410.000000        0
#
# [103 rows x 6 columns]

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x=cluster_df.drop(['cluster'],axis=1)
y=cluster_df['cluster']

# %%
model=DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=100)

# %%
#from numbers import Rational
#train_size and test_size divides the data
#How rows will be passed in what Ratio

#Random state tells us in what way our rows and columns will be passed to out model

# %%
xtrain.shape
# Out:
# (82, 5)

# %%
model.fit(xtrain,ytrain)
ypred=model.predict(xtest)

# %%
confusion_matrix(ytest,ypred)
# Out:
# array([[ 4,  0,  0],
#        [ 0, 14,  0],
#        [ 0,  0,  3]])

# %%
print(accuracy_score(ytest,ypred))
# Out:
# 1.0

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00         3
#
#     accuracy                           1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
